# %% [markdown]
# # Amazon sales data analysis 1

# %% [markdown]
# ## <span style="color: skyblue;"> Agenda </span>
#
# - Amazon Sales Dataset introduction and loading
# - Merging dataframes
# - Applying functions with .apply()
# - Grouping in Pandas

# %% [markdown]
# ### About the Dataset and Business Case of Amazon
#
# **Dataset:** <font color="violet">**Retail Product Reviews**</font> 🛍
# We are exploring a retail dataset that includes **product information** and **customer reviews**. By analyzing this data, we aim to understand:
#
# - Trends in <font color="blue">**product ratings**</font> and <font color="green">**discount effectiveness**</font>.
# - Insights from <font color="purple">**customer reviews**</font> to assess product reception.
# - Relationships between <font color="orange">**pricing, discounts, and ratings**</font>.
# - The significance of <font color="red">**categories**</font> in influencing purchasing behavior.
#
# ### **Key Business Objectives:**
# 1. <font color="teal">**Enhance Customer Experience**</font>: Understand customer sentiment through reviews and ratings.
# 2. <font color="teal">**Boost Revenue with Discounts**</font>: Analyze the effect of discount percentages on sales and reviews.
# 3. <font color="teal">**Product Optimization**</font>: Identify top-performing product categories for focused marketing strategies.
# 4. <font color="teal">**Inform Pricing Strategies**</font>: Use insights from rating trends and pricing.
#
# We’ll use this dataset as a running example to demonstrate techniques in data analysis and, later, how <font color="magenta">**NumPy**</font> and <font color="magenta">**pandas**</font> can simplify merging and analyzing structured data efficiently.
#
# <font color="blue">**Note:**</font> Here is our initial look at the data. We see columns like:
# - <font color="orange">`product_id`</font> (unique identifier for products, key for merging datasets)
# - <font color="purple">`review_content`</font> & <font color="green">`rating`</font> (customer feedback and sentiment analysis)
# - <font color="red">`discount_percentage`</font> & <font color="brown">`actual_price`</font> (pricing insights)
#
# This dataset offers a rich foundation to explore merging operations and practical use cases in retail analytics.
#
# Now, we will be loading the dataset that includes product information and customer reviews.

# %% [markdown]
# ### **Dataset Link:** <span style="background-color: Blue;">[Amazon Sales Data](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip)</span>
#
# ### Loading the dataset

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Out:
# --2026-04-28 09:18:24--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.170.7.32, 3.170.7.158, 3.170.7.76, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.170.7.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943535 (1.9M) [application/zip]
# Saving to: ‘amazon_data4.zip’
#
# amazon_data4.zip    100%[===================>]   1.85M  --.-KB/s    in 0.01s
#
# 2026-04-28 09:18:24 (144 MB/s) - ‘amazon_data4.zip’ saved [1943535/1943535]

# %%
# !unzip amazon_data4.zip
# Out:
# Archive:  amazon_data4.zip
#   inflating: products.csv
#   inflating: orders.csv

# %% [markdown]
# #### Reading the dataset:
#
# #### Code:

# %%
import pandas as pd

orders = pd.read_csv('orders.csv')
orders.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# ...

# %%
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                 category discounted_price actual_price  rating  rating_count  \
# 0  Computers&Accessories             ₹399       ₹1,099     4.2       24269.0
# 1  Computers&Accessories             ₹199         ₹349     4.0       43994.0
# 2  Computers&Accessories             ₹199       ₹1,899     3.9        7928.0
# 3  Computers&Accessories             ₹329         ₹699     4.2       94363.0
# 4  Computers&Accessories             ₹154         ₹399     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %% [markdown]
# ### AI Pattern: Let AI Profile Your Dataset (new part)
# Before diving into analysis, data scientists do a quick "health check" on the data. You can feed a summary to AI and let it flag things you might miss.
#
# > Ask Gemini AI to discover some key insights about the above dataset for you.

# %% [markdown]
# Now, we will be learning how to merge these two datasets.

# %% [markdown]
# ## <span style="color: skyblue;"> Merging DataFrames </span>
#
# Just like we can merge two Excel sheets, we can also merge two dataframes.
#
#
# #### Concatenation:
# `pd.concat()` is used to stack DataFrames either **vertically (rows) or horizontally (columns)**. However, it doesn’t align DataFrames based on keys.
#
# ![1](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/153/922/original/1.png?1758519701)
#
# - `axis = 0` - merging along rows
# - `axis = 1` - merging along columns
#
# #### Merge:
# `pd.merge()` allows you to combine DataFrames based on **one or more keys (common columns)**. This aligns rows based on these keys, making it more flexible and accurate for relational joins.
#
# ![2](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/153/924/original/2.png?1758520194)
#
# This `merge` operation is done along a unique column to have a relation between the two dataframes.
#
#
# ## <span style="color: skyblue;"> Joins in SQL </span>
#
#
# We are assuming that most of you might have learnt joins in SQL.
#
# ![3](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/153/926/original/3.webp?1758520912)
#
#
# **Joins in pandas** replicate SQL-style joins:
# - **Inner Join**: Returns rows with matching keys in both DataFrames.
# - **Outer Join**: Returns all rows, with missing values filled as `NaN`.
# - **Left Join**: Keeps all rows from the left DataFrame and matches from the right.
# - **Right Join**: Keeps all rows from the right DataFrame and matches from the left.
#
# > [Interactive]: Visualize how merge and join operations combine datasets step by step before diving into the code:
# [Merge & Join Visualizer](https://aiml-v-izs.vercel.app/v/az-j9x3r6t1/pd-merging?embed=1)
#
#
# Let's understand these joins using a sample dataset:
#
# **Inner Join**: Combines only matching rows based on product_id.
#
# #### Code:

# %%
# Import pandas
import pandas as pd

# Sample DataFrames
samples_orders = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P003'],
    'user_id': ['U001', 'U002', 'U003'],
    'review_id': ['R001', 'R002', 'R003']
})

samples_products = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P004'],
    'product_name': ['Product A', 'Product B', 'Product D'],
    'category': ['Category 1', 'Category 2', 'Category 3']
})

# Inner Join Example
inner_join = pd.merge(samples_orders, samples_products, on='product_id', how='inner')
print("Inner Join:")
print(inner_join)
# Out:
# Inner Join:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2

# %% [markdown]
# - We can see that the common column is `product_id`.
# - Hence, the joins are based on the `product_id`.
# - In an inner join, only the common IDs are joined, and the rest are ignored.
#
#
# <span style="background-color: red;"> **[Ask Learners]:** </span>
# Try the other types of joins (`outer`, `left` and `right`) now and observe the differences. Let learner try them out.
#
# **Outer Join**
# Combines all rows from both DataFrames, filling unmatched columns with `NaN`.
#
# #### Code:

# %%
# Outer Join Example
outer_join = pd.merge(samples_orders,
                      samples_products, on='product_id', how='outer')
print("\nOuter Join:")
print(outer_join)
# Out:
# Outer Join:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2
# 2       P003    U003      R003          NaN         NaN
# 3       P004     NaN       NaN    Product D  Category 3

# %% [markdown]
# To learn about the syntax, you can use the help page by just writing `pd.merge`.
#
#
# ### <span style="color: violet;"> **Which Join is Best in Our Case?** </span>
#
# #### **Best Join: Left Join**
# For our scenario, the **Left Join** is the best choice because:
# 1. It keeps all rows from the `orders` DataFrame.
# 2. It adds product information only for matching `product_ids, leaving unmatched products as `NaN`.
#
# This ensures we don’t lose any `orders` data while still enriching the dataset with available product details.
#
# > **Tip: When Column Names are Different**
# > Sometimes the common key has different names in both DataFrames. For example, the left DataFrame may have `product_id` and the right DataFrame may have `id`. In that case, use `left_on` and `right_on` instead of `on`:
# > ```python=
# > pd.merge(orders, products, left_on="product_id", right_on="id", how="left")
# > ```
# > This is similar to SQL joins where we mention columns from both tables explicitly.
#
#
# #### Code:

# %%
# Performing a Left Join to merge orders with product details
df = pd.merge(orders, products, on='product_id', how='left')

# Displaying the result
print("Best Join (Left Join) for Our Use Case:")
df.head()
# Out:
# Best Join (Left Join) for Our Use Case:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %% [markdown]
# # Question
# What does `how="outer"` do in `pd.merge()`?
# # Choices
# - [ ] Returns only matching rows from both DataFrames
# - [ ] Returns all rows from the left DataFrame only
# - [x] Returns all rows from both DataFrames, filling missing values with NaN
# - [ ] Returns only non-matching rows
#
# Explanation: An outer join includes all rows from both DataFrames. Where there is no match, Pandas fills the missing values with NaN.

# %% [markdown]
# # <span style="color: skyblue;"> Applying Functions with `.apply()` </span>
#
# `.apply()` is a powerful method in pandas to apply custom or predefined functions to DataFrame columns or rows.
#
#
# #### Code:

# %%
df['review_title'].head()
# Out:
# 0    Satisfied,Charging is really fast,Value for mo...
# 1    Satisfied,Charging is really fast,Value for mo...
# 2    Satisfied,Charging is really fast,Value for mo...
# 3    A Good Braided Cable for Your Type C Device,Go...
# 4    A Good Braided Cable for Your Type C Device,Go...
# Name: review_title, dtype: object

# %% [markdown]
# Now, we have a dataset with the column `review_title`. We want to convert this data into `Uppercase`.

# %%
def uppercase_title(title):
    return title.upper()

df['review_title_uppercase'] = df['review_title'].apply(uppercase_title)

df['review_title_uppercase'].head()
# Out:
# 0    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 1    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 2    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 3    A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# 4    A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# Name: review_title_uppercase, dtype: object

# %% [markdown]
# This operation can also be performed using a lambda function.

# %%
orders['review_title_uppercase'] = orders['review_title'].apply(lambda x: x.upper())

df['review_title_uppercase'].head()
# Out:
# 0    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 1    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 2    SATISFIED,CHARGING IS REALLY FAST,VALUE FOR MO...
# 3    A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# 4    A GOOD BRAIDED CABLE FOR YOUR TYPE C DEVICE,GO...
# Name: review_title_uppercase, dtype: object

# %% [markdown]
# - In the above code, `x` is the input for the function.
#
# Let's do some interesting operations on the datasets:
#
# #### Code:

# %%
print(df['discounted_price'].head())
print(df['actual_price'].head())
# Out:
# 0    ₹399
# 1    ₹399
# 2    ₹399
# 3    ₹199
# 4    ₹199
# Name: discounted_price, dtype: object
# 0    ₹1,099
# 1    ₹1,099
# 2    ₹1,099
# 3      ₹349
# 4      ₹349
# Name: actual_price, dtype: object

# %% [markdown]
# Let's remove the `rupee` symbol and `,` from the above datasets and convert them in integer.
#
# #### Code:

# %%
def extract_price(price_str):
    try:
        return float(str(price_str).replace('₹', '').replace(',', ''))
    except ValueError:
        return None

# Apply the function to the 'actual_price' and 'discounted_price' columns
df['actual_price'] = df['actual_price'].apply(extract_price)
df['discounted_price'] = df['discounted_price'].apply(extract_price)

print(df['discounted_price'].head())
print(df['actual_price'].head())
# Out:
# 0    399.0
# 1    399.0
# 2    399.0
# 3    199.0
# 4    199.0
# Name: discounted_price, dtype: float64
# 0    1099.0
# 1    1099.0
# 2    1099.0
# 3     349.0
# 4     349.0
# Name: actual_price, dtype: float64

# %% [markdown]
# <span style="background-color: red;"> **[Ask Learners]:** </span>
# <span style="color: violet;"> How can we find the discount percentage from these two columns? </span>
#
# Now, let's calculate the discount percentage for the product items.
#
# #### Code:

# %%
# Define a function to calculate the effective discount percentage
def calculate_discount_percentage(row):
    return ((row['actual_price'] - row['discounted_price']) / row['actual_price']) * 100

# Apply the function along rows (axis=1)
df['calculated_discount'] = df.apply(calculate_discount_percentage, axis=1)

# Display the result
print("Products DataFrame with Calculated Discounts:")
df[['product_name', 'actual_price', 'discounted_price', 'calculated_discount']].head()
# Out:
# Products DataFrame with Calculated Discounts:
#                                         product_name  actual_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...        1099.0
# 1  Wayona Nylon Braided USB to Lightning Fast Cha...        1099.0
# 2  Wayona Nylon Braided USB to Lightning Fast Cha...        1099.0
# 3  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...         349.0
# 4  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...         349.0
#
#    discounted_price  calculated_discount
# 0             399.0            63.694268
# 1             399.0            63.694268
# 2             399.0            63.694268
# 3             199.0            42.979943
# 4             199.0            42.979943

# %% [markdown]
# - One important point to remember is that `axis = 1` must be assigned to ensure that the operations are performed along the rows.
#
#
# Let's see how can we execute multiple operations for multiple columns.
#
# #### Code:

# %%
# Define aggregate functions to calculate max and min
def max_rating(series):
    return series.max()

def min_rating_count(series):
    return series.min()

# Apply the functions across columns
rating_stats = products[['rating', 'rating_count']].apply([max_rating, min_rating_count])

# Display the result
print("Rating Statistics:")
print(rating_stats)
# Out:
# Rating Statistics:
#                   rating  rating_count
# max_rating           5.0      426973.0
# min_rating_count     2.0           2.0

# %% [markdown]
# # Question
# Which of the following is the most accurate description of `.apply()` with `axis=1`?
# # Choices
# - [ ] It vectorizes row-wise operations across all columns.
# - [x] It applies the function once per row, passing the entire row as a Series.
# - [ ] It applies the function on each column separately.
# - [ ] It modifies the DataFrame inplace without returning anything.
#
#
# Explanation: `axis=1` → function applied row by row, with each row passed as a Series. This is not vectorized; it’s slower. Many confuse it with NumPy-style row-wise vectorization.

# %% [markdown]
# ### AI Pattern: "Show Me 3 Ways" (new part)
# In Pandas, there are almost always multiple ways to do the same thing. Some are faster, some are more readable. AI can show you alternatives you wouldn't know to search for.

# %%
# New Part
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get('Gemini-API'))
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
response = model.generate_content(
    contents="""I calculated discount percentage in Pandas using .apply() with axis=1:

df['calculated_discount'] = df.apply(
    lambda row: ((row['actual_price'] - row['discounted_price']) / row['actual_price']) * 100,
    axis=1
)

Show me 3 different ways to achieve the same result in Pandas:
1. The vectorized way (no .apply)
2. Using .eval()
3. Using np.where to handle division by zero

For each, show the code and one line on when you'd prefer it."""
)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3438.76ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3943.74ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3058.61ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2882.41ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6918.16ms
# You're right to look for alternatives to `.apply(axis=1)` for performance reasons, as it can be significantly slower than vectorized operations in Pandas.
#
# Here are three different ways to achieve the same result, along with their preferences:
#
# First, let's set up a sample DataFrame including a case that would cause division by zero:
#
# ...

# %% [markdown]
# # <span style="color: skyblue;"> Grouping in Pandas </span>
#
# Grouping is a powerful feature in pandas that allows us to perform operations on subsets of the data. The process can be broken down into three main steps:
#
# 1. **Split:** Divide the data into groups based on a key or multiple keys.
# 2. **Apply:** Perform a specific operation (e.g., aggregation, transformation, or filtering) on each group.
# 3. **Combine:** Bring the results together into a new DataFrame or Series.
#
# Let's see this example to understand it visually.
#
# ![4](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/153/929/original/4.png?1758524042)
#
# > [Interactive]: Visualize how groupby splits data into groups based on keys before applying any operations:
# [GroupBy Split Visualizer](https://aiml-v-izs.vercel.app/v/az-j9x3r6t1/pd-groupby-split?embed=1)
#
# > Note: This only visualize the splits like the above image.
#
# ### Simple Grouping Idea
#
# Suppose we have a dataset like this:
#
# <img src=https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/192/402/original/Screenshot_2026-04-24_094958.png?1777004412 width=150>
#
# If we group by `key`, then:
# * All `A` rows go together
# * All `B` rows go together
# * All `C` rows go together
#
# Then if we apply `sum()`:
# * A becomes `1 + 4 = 5`
# * B becomes `2 + 5 = 7`
# * C becomes `3 + 6 = 9`
#
# This is the basic idea of grouping.
#
#
# ### <span style=color:orange> Business Context:</span>
#
# Amazon handles vast amounts of data across its e-commerce platform, including customer orders, product sales, and inventory records. Grouping data by keys like product categories, regions, or customer segments allows Amazon to analyze trends, optimize inventory, and tailor marketing strategies. Using pandas’ grouping functionality, Amazon can split data (e.g., by product category), apply operations like summing sales or averaging ratings, and combine results to generate actionable insights. This supports critical business decisions, such as identifying top-performing product categories, optimizing stock levels, or personalizing customer recommendations.
#
#
# ## **1. Group-Based Aggregations**
#
# We can use <font color="magenta">`.groupby()`</font> to perform aggregation functions such as `sum`, `min`, `max`, `count`, etc., for each group. Let’s start with some examples.
#
# > [Interactive]: See how groupby applies aggregate functions to each group and combines the results step by step:
# [GroupBy Aggregation Visualizer](https://aiml-v-izs.vercel.app/v/az-j9x3r6t1/pd-groupby?embed=1)
#
# > Show different operation from dropdown about aggregate.
#
#
# **Example 1: Group by a Single Column**
# - **Goal:** Find the average `calculated_discount` for each `category`.
#
# > **Business Question:** For each category, what is the average discount being offered?
# >
# > Example categories: Electronics, Clothing, Books.
# >
# > After grouping by `category`, values are separated like this:
# > * Electronics: `20`, `18` → Average: `(20 + 18) / 2 = 19`
# > * Clothing: `35`, `30` → Average: `(35 + 30) / 2 = 32.5`
# > * Books: `10`, `12` → Average: `(10 + 12) / 2 = 11`
# >
# > For example, Laptop may have 10% discount and Mobile may have 20% discount — both in Electronics — so average discount for Electronics = `(10 + 20) / 2 = 15`. This helps understand how much discount is offered category-wise.
# >
# > **Note:** To drill down further, group by subcategory instead: `df.groupby("subcategory")["discount_percentage"].mean()`
# >
# > <span style="color: red;">Important:</span> Whatever column you want to group data by, that column should be passed inside `groupby()`.
#
# #### Code:

# %%
## How can Amazon analyze average discount percentages by product category to identify which categories
## have the most effective discount strategies for driving sales?

# Example 1: Group by 'category' and calculate the average 'discounted_price'
avg_discounted_price = df.groupby('category')['calculated_discount'].mean()

# Display the results
print("Average Discounted Percentage by Category:")
avg_discounted_price
# Out:
# Average Discounted Percentage by Category:
# category
# Car&Motorbike            41.525000
# Computers&Accessories    55.374270
# Electronics              52.152439
# Health&PersonalCare      52.684211
# Home&Kitchen             40.241448
# HomeImprovement          57.944088
# MusicalInstruments       45.808298
# OfficeProducts           12.771811
# Toys&Games                0.000000
# Name: calculated_discount, dtype: float64

# %% [markdown]
# **Example 2: Count of products per user**
#
# - **Goal:** Compute the count `product` for each `user`.
#
# > **Business Question:** For each user, how many products are associated with them?
# >
# > Simple idea: If Alice has 3 product rows and Bob has 2 product rows, after groupby + count we get Alice → 3, Bob → 2.
# >
# > **Key idea:** Grouping is not limited to numeric columns. We can group by a text column and count another column. This is useful for questions like:
# > * How many products did each user review?
# > * How many orders did each customer place?
# > * How many records exist per category?
# > * How many transactions belong to each city?
#
# #### Code:

# %%
# Example:
count_product_user = df.groupby('user_name')['product_name'].count()
count_product_user[:10]
# Out:
# user_name
# $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger Planet,Justice ⚖️,indrajyoti d.,Aditya Kumar,E.C.GEORGE                             16
# & I Am IronMan,Amazon Customer,Sayandeep Sarkar,sherin                                                                            1
# (sic),Harshit,Bharath N,Pulkit Malik,Akhtar Anwar,Amar  Thapa,Chandan kumar,vijay                                                 1
# 123MovieTime,Ravneet S.,Akash,Mohd Amaan,Pankaj,Sajan                                                                             1
# 9640185788,Piyush Mishra,Vickie,Sakshi gupta,Srinivas,Lovraj V.,Rakshitha,Sandeep Kumar Yadav                                     1
# 9848023076,Parimala,ajay kumar verma,ARSHAD,Hola,Anil V,kuppannan maruthachalam,Nikhil                                            1
# A H.,Amazon Customer,Amazon Customer,Gajendra Kumar sharma,Harpreet Kaur Sodhi,Shashi ranjan Kumar,Chandan Kumar,Vikas sharma     1
# ...

# %% [markdown]
# **Example 3: Maximum and Minimum Rating Count by Category and Product Name**
# - **Goal:** Find the maximum and minimum `rating_count` for each combination of `category` and `product_name`.
#
# > **Business use case:** Suppose the same product exists across multiple platforms. For example, Amazon has iPhone rating count as `4230` and Flipkart has iPhone rating count as `3950`. Grouping by both `category` and `product_name` and applying `agg(["max", "min"])` lets us know the highest and lowest rating count for that product — helping compare product popularity across different platforms or sources.
#
# #### Code:

# %%
# Example: Maximum and minimum rating count by category and product name
rating_stats = df.groupby(['category', 'product_name'])['rating_count'].agg(['max', 'min'])

print("\nMaximum and Minimum Rating Count by Category and Product Name:")
rating_stats[:10]
# Out:
# Maximum and Minimum Rating Count by Category and Product Name:
#                                                                               max  \
# category              product_name
# Car&Motorbike         Reffair AX30 [MAX] Portable Air Purifier for Ca...   1118.0
# Computers&Accessories APC Back-UPS BX600C-IN 600VA / 360W, 230V, UPS ...  15783.0
#                       Acer EK220Q 21.5 Inch (54.61 cm) Full HD (1920x...   2014.0
#                       Agaro Blaze USBA to micro +Type C 2in1 Braided ...  14184.0
#                       AirCase Protective Laptop Bag Sleeve fits Upto ...   9940.0
#                       AirCase Protective Laptop Bag Sleeve fits Upto ...   9701.0
#                       AirCase Protective Laptop Bag Sleeve fits Upto ...  11330.0
#                       AirCase Rugged Hard Drive Case for 2.5-inch Wes...  21010.0
#                       Airtel AMF-311WW Data Card (Black), 4g Hotspot ...  11213.0
# ...

# %% [markdown]
# ## **2. Group-Based Filtering**
#
# Group-based filtering in pandas allows us to retain groups that satisfy certain conditions. This is done using <font color="magenta">`.filter()`</font> on grouped DataFrames.
#
# > [Interactive]: See how groupby filters groups based on conditions step by step before diving into the code:
# [GroupBy Filter Visualizer](https://aiml-v-izs.vercel.app/v/az-j9x3r6t1/pd-groupby?embed=1)
#
# > Select the operation  filter from dropdown.
#
# Here are some examples of group-based filtering using different columns from the **merged DataFrame**:
#
# **Example 1: Filter Categories with Average Rating equal or above 4**
# - **Goal:** Keep only categories where the average `rating` is greater than or equal to 4.
#
#
#
# ### <span style=color:orange> Business Context:</span>
#
#
# Amazon’s e-commerce platform relies on product ratings to build customer trust and drive sales. Filtering product categories based on metrics like average ratings helps Amazon identify high-quality categories that meet customer expectations. Using pandas’ .filter() on grouped DataFrames allows Amazon to isolate categories with strong performance (e.g., average rating ≥ 4), enabling targeted marketing, quality assurance, or inventory prioritization. This ensures Amazon promotes top-rated categories, enhancing customer satisfaction and optimizing product offerings.
#
# #### Code:

# %%
# Example: Filter categories with an average rating >= 4
categories_high_rating = df.groupby('category')['rating'].mean().loc[lambda x: x >= 4]

# Display the results
print("Categories with High Average Rating (Above 4):")
categories_high_rating
# Out:
# Categories with High Average Rating (Above 4):
# category
# Computers&Accessories    4.158934
# Electronics              4.090508
# Health&PersonalCare      4.000000
# Home&Kitchen             4.045890
# HomeImprovement          4.250000
# OfficeProducts           4.309677
# Toys&Games               4.300000
# Name: rating, dtype: float64

# %% [markdown]
# **Example 2: Filter Users Who Have Written More Than 15 Reviews**
# - **Goal:** Retain only users (`user_id`) who have written more than 15 reviews.
#
# > **Business use case:** Amazon may want to identify users who write many reviews. Such users may be:
# > * Highly engaged customers
# > * Power users
# > * Useful reviewers
# > * Candidates for feedback programs or loyalty rewards
# >
# > Example: User 1 wrote 70 reviews → kept. User 2 wrote 8 reviews → removed. User 3 wrote 20 reviews → kept.
#
# #### Code:

# %%
# Example: Filter users who have written more than 15 reviews
users_with_many_reviews = df.groupby('user_id').filter(
    lambda group: group['review_id'].count() > 15
)

users_with_many_reviews
# Out:
#      product_id                                            user_id  \
# 3    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 5    B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 25   B082LZGK39  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 26   B082LZGK39  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 44   B082LSVT4B  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 45   B082LSVT4B  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 57   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 58   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 59   B09NHVCHS9  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 98   B09NJN8L25  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 160  B09NKZXMWJ  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# 258  B0B3N8VG24  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# ...

# %% [markdown]
# <span style =color:violet>Notice what's happening here?</span>
#
# - We first group data by director and then use `groupby().filter` function.
# - **Groups are filtered if they do not satisfy the boolean criterion** specified by the function.
# - This is called **Group Based Filtering**.
#
# <span style =color:red>**Note:**</span>
# - We are filtering the **groups** here and **not the rows**.
# - The result is **not a groupby object** but regular **Pandas DataFrame** with the **filtered groups eliminated**.
#
#
# ## **3. Group-Based Apply**
#
# The <font color="magenta">`.apply()`</font> method allows us to perform **custom operations** on each group, enabling advanced transformations and computations.
#
# ### <span style=color:orange> Business Context:</span>
#
# Amazon’s vast e-commerce ecosystem generates complex datasets, including customer orders, product reviews, and sales data, which require customized transformations to derive actionable insights. Using pandas’ .apply() with grouped data enables Amazon to perform tailored computations on subsets, such as calculating custom metrics per product category or user segment. This supports strategic decisions like optimizing pricing, personalizing customer recommendations, or identifying top-performing products, ultimately enhancing customer satisfaction and operational efficiency.
#
# > [Interactive]: Explore how groupby apply runs custom functions on each group step by step before diving into the code:
# [GroupBy Apply Visualizer](https://aiml-v-izs.vercel.app/v/az-j9x3r6t1/pd-groupby?embed=1)
#
# > Select the operation for apply from dropdown
#
#
# Here are some examples of group-based operations using `.apply()`:
#
# **Example 1: Group-based apply with a custom function**
#
# Here, we group by category and use apply with a custom function that calculates the difference between average actual price and average discounted price. This might help show how much discount each category usually has.
#
# #### Code:

# %%
# Example 1: Group-based apply with a custom function

# Define a custom function to compute average price difference for each group
def avg_price_diff(group):
    # We handle potential missing data
    avg_actual = group['actual_price'].mean()
    avg_discounted = group['discounted_price'].mean()
    return avg_actual - avg_discounted

# Apply this function to each group (category) in df
price_diff_by_category = df.groupby('category').apply(avg_price_diff)

price_diff_by_category
# Out:
# /tmp/ipykernel_5566/3340978438.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   price_diff_by_category = df.groupby('category').apply(avg_price_diff)
# category
# Car&Motorbike            1661.000000
# Computers&Accessories     740.857453
# Electronics              4143.782554
# Health&PersonalCare      1001.000000
# Home&Kitchen             1857.723325
# HomeImprovement           462.000000
# MusicalInstruments        709.000000
# OfficeProducts             65.686022
# Toys&Games                  0.000000
# dtype: float64

# %% [markdown]
# - **Example 2 using .apply()**
#
#
# The goal is to compute mean rating, min discounted price, and max discounted price by category. We define a custom function that returns a pd.Series containing these statistics:
#
# #### Code:

# %%
# Example 2 using .apply()

# Define a custom aggregation function
def my_aggregations(group):
    return pd.Series({
        'mean_rating': group['rating'].mean(),
        'min_discounted_price': group['discounted_price'].min(),
        'max_discounted_price': group['discounted_price'].max()
    })

# Apply custom function after grouping by 'category'
stats_by_category = df.groupby('category').apply(my_aggregations)

print(stats_by_category)
# Out:
#                        mean_rating  min_discounted_price  max_discounted_price
# category
# Car&Motorbike             3.800000                2339.0                2339.0
# Computers&Accessories     4.158934                  39.0               37247.0
# Electronics               4.090508                  79.0               77990.0
# Health&PersonalCare       4.000000                 899.0                 899.0
# Home&Kitchen              4.045890                  79.0               42990.0
# HomeImprovement           4.250000                 249.0                 425.0
# MusicalInstruments        3.900000                 478.0                 798.0
# OfficeProducts            4.309677                  50.0                1399.0
# Toys&Games                4.300000                 150.0                 150.0
# ...

# %% [markdown]
# - **Example 3: Creating a new column during groupby apply, then filtering with .loc**
#
# Below is an additional example that creates a new column via a custom function and uses the group keys. Afterward, we use .loc to filter out certain rows based on our newly created column.
#
#
# #### Code:

# %%
# Example: Creating a new column during groupby apply, then filtering with .loc

# Let's define a custom function to classify reviews by "rating"
def add_review_status(group):
    # Create a new column in each group based on the rating
    group['review_status'] = group['rating'].apply(
        lambda x: 'Good' if x is not None and x > 4.2 else 'Not Good'
    )
    return group

# We group by 'category', and use group_keys=True (this ensures the group labels are preserved)
df_with_status = df.groupby('category', group_keys=True).apply(add_review_status)

df_with_status
# Out:
# /tmp/ipykernel_5566/124281565.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_with_status = df.groupby('category', group_keys=True).apply(add_review_status)
#                             product_id  \
# category
# Car&Motorbike         1429  B0912WJ87V
# Computers&Accessories 0     B07JW9H4J1
#                       1     B07JW9H4J1
#                       2     B07JW9H4J1
#                       3     B098NS6PVG
# ...                                ...
# OfficeProducts        1259  B00S2SEV7K
#                       1269  B086Q3QMFS
#                       1271  B07LFQLKFZ
#                       1272  B00LY17RHI
# Toys&Games            1171  B00DJ5N9VK
#
# ...

# %% [markdown]
# <span style=color:red>**Note:**</span>
# - Setting `group_keys=True`, keeps the group key in the returned dataset.
# - This will be default in future versions of Pandas.
# - Keep it as False if want the normal behaviour.
#
#
# #### Code:

# %%
# Now we can filter rows using .loc based on the newly created column
# For example, let's keep only rows labeled as 'Good'
filtered_df = df_with_status.loc[df_with_status['review_status'] == 'Good']

filtered_df.head(10)
# Out:
#                           product_id  \
# category
# Computers&Accessories 21  B08DDRGWTJ
#                       22  B08DDRGWTJ
#                       27  B08CF3D7QR
#                       28  B08CF3D7QR
#                       29  B08CF3D7QR
#                       40  B083342NKJ
#                       41  B083342NKJ
#                       42  B083342NKJ
#                       50  B09C6HXFC1
#                       51  B09C6HXFC1
#
#                                                                     user_id  \
# category
# Computers&Accessories 21  AHW6E5LQ2BDYOIVLAJGDH45J5V5Q,AF74RSGCHPZITVFSZ...
#                       22  AHW6E5LQ2BDYOIVLAJGDH45J5V5Q,AF74RSGCHPZITVFSZ...
#                       27  AGYLPKPZHVYKKZHOTHCTYVEDAJ4A,AGTTU64JMX722LYCN...
#                       28  AGYLPKPZHVYKKZHOTHCTYVEDAJ4A,AGTTU64JMX722LYCN...
#                       29  AGYLPKPZHVYKKZHOTHCTYVEDAJ4A,AGTTU64JMX722LYCN...
# ...

# %% [markdown]
# # Question
# You run:

# %%
df.groupby("Region")["Sales"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5566/3700758311.py in <cell line: 0>()
# ----> 1 df.groupby("Region")["Sales"].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %% [markdown]
# Which statement is correct?
#
# # Choices
# - [ ] The output must be a DataFrame.
# - [x] The output will be a Series indexed by "Region".
# - [ ] The output must contain the original index of `df`.
# - [ ] GroupBy always returns the same type regardless of aggregation.
#
# Explanation: When selecting a single column before aggregation, the result is a Series. If multiple columns are aggregated, it’s a DataFrame. Subtle but critical difference.

# %% [markdown]
# ## <span style="color: skyblue;"> Series and DataFrame Output from Groupby </span>
#
# If grouped output has a single value per group, Pandas often returns a **Series**.
#
# Example:

# %%
# Sample DataFrame
df = pd.DataFrame({
    "region": ["North", "South", "East", "West", "North", "South", "East", "West"],
    "score": [85, 90, 78, 88, 92, 95, 80, 84],
    "sales": [200, 250, 180, 220, 210, 260, 190, 230]
})

# %%
df.groupby("region")["score"].mean()
# Out:
# region
# East     79.0
# North    88.5
# South    92.5
# West     86.0
# Name: score, dtype: float64

# %% [markdown]
# This returns one labeled value per group — it behaves like a Pandas Series because it is one labeled list.
#
# If multiple columns or multiple values are returned, the output behaves more like a **DataFrame**.
#
# **Simple rule:**
# * Single labeled list → **Series**
# * Multiple columns together → **DataFrame**
#
# A DataFrame can be thought of as a collection of multiple Series.
#
# > <span style="color: red;">**Important:**</span> In `groupby`, visualizing the flow is very important. First understand:
# > * What column is used for grouping
# > * What operation is applied inside each group
# > * What output is expected from each group
# >
# > This mental model makes groupby operations much easier to understand and remember.

# %% [markdown]
# ### AI Integration: Ask the Gemini AI to return a summary of this lecture (new part)
