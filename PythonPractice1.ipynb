# %%
import sys
sys.version

2+3
105-10
# Out:
# 95

# %%
5*4
# Out:
# 20

# %% [markdown]
# Numbers in python

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
X_train, Y_train, X_test, Y_test = 30, 14, 23,66
X_train
X_test
Y_train
Y_test
# Out:
# 66

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
InputA = 123
InputA
type(InputA)
# Out:
# int
